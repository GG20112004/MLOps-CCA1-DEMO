# %%
import wandb
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris

wandb.init(project="cca1-mlops-demo", name="notebook-run")

X, y = load_iris(return_X_y=True)
model = RandomForestClassifier(n_estimators=50, max_depth=3)
model.fit(X, y)
acc = model.score(X, y)

print("Accuracy:", acc)
wandb.log({"accuracy": acc})
wandb.finish()
# Out:
# Tracking run with wandb version 0.30.0
# Run data is saved locally in <code>C:\Users\Shree Gowri\OneDrive\Desktop\cca1-demo\wandb\run-20260920_123857-mhkgpxd3</code>
# Syncing run <strong><a href='https://wandb.ai/shreegowrirk-bmsit/cca1-mlops-demo/runs/mhkgpxd3' target="_blank">notebook-run</a></strong> to <a href='https://wandb.ai/shreegowrirk-bmsit/cca1-mlops-demo' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/shreegowrirk-bmsit/cca1-mlops-demo' target="_blank">https://wandb.ai/shreegowrirk-bmsit/cca1-mlops-demo</a>
#  View run at <a href='https://wandb.ai/shreegowrirk-bmsit/cca1-mlops-demo/runs/mhkgpxd3' target="_blank">https://wandb.ai/shreegowrirk-bmsit/cca1-mlops-demo/runs/mhkgpxd3</a>
# Accuracy: 0.96
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">notebook-run</strong> at: <a href='https://wandb.ai/shreegowrirk-bmsit/cca1-mlops-demo/runs/mhkgpxd3' target="_blank">https://wandb.ai/shreegowrirk-bmsit/cca1-mlops-demo/runs/mhkgpxd3</a><br> View project at: <a href='https://wandb.ai/shreegowrirk-bmsit/cca1-mlops-demo' target="_blank">https://wandb.ai/shreegowrirk-bmsit/cca1-mlops-demo</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260920_123857-mhkgpxd3\logs</code>
